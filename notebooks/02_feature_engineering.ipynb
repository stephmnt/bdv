# %% [markdown]
# # 02 - Feature engineering
#
# Transformation du format long en variables explicatives par bloc et par bureau.

# %%
from pathlib import Path
import sys

PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.append(str(PROJECT_ROOT))

import pandas as pd
import numpy as np

RAW_DIR = PROJECT_ROOT / "data" / "raw"
INTERIM_DIR = PROJECT_ROOT / "data" / "interim"
PROCESSED_DIR = PROJECT_ROOT / "data" / "processed"

mapping_path = PROJECT_ROOT / "data" / "mapping_candidats_blocs.csv"

pd.set_option("display.max_columns", 50)

# %% [markdown]
# ## Chargement du format long

# %%
if (INTERIM_DIR / "elections_long.parquet").exists():
    elections_long = pd.read_parquet(INTERIM_DIR / "elections_long.parquet")
else:
    elections_long = pd.read_csv(INTERIM_DIR / "elections_long.csv", sep=";")

elections_long.head()
# Out:
#      code_bv  nom_bv  annee date_scrutin type_scrutin  tour  inscrits  \
# 0  000010001     NaN   2014   2014-05-25  europeennes     1      1193
# 1  000010001     NaN   2014   2014-05-25  europeennes     1      1193
# 2  000010001     NaN   2014   2014-05-25  europeennes     1      1193
# 3  000010001     NaN   2014   2014-05-25  europeennes     1      1193
# 4  000010001     NaN   2014   2014-05-25  europeennes     1      1193
#
#    votants  abstentions  blancs  nuls  exprimes code_candidature  \
# 0      566          NaN     NaN   NaN       549             <NA>
# 1      566          NaN     NaN   NaN       549             <NA>
# 2      566          NaN     NaN   NaN       549             <NA>
# 3      566          NaN     NaN   NaN       549             <NA>
# 4      566          NaN     NaN   NaN       549             <NA>
#
#   nom_candidature  voix  N° tour Code du département Code de la commune  \
# 0            <NA>   0.0      1.0                  34                  1
# 1            <NA>   0.0      1.0                  34                  1
# 2            <NA>   0.0      1.0                  34                  1
# 3            <NA>   0.0      1.0                  34                  1
# 4            <NA>   0.0      1.0                  34                  1
#
#   Nom de la commune Numéro bureau de vote  NÂ° de dépôt du candidat 1  \
# 0          Abeilhan                  0001                         2.0
# 1          Abeilhan                  0001                         3.0
# 2          Abeilhan                  0001                         4.0
# 3          Abeilhan                  0001                         5.0
# 4          Abeilhan                  0001                         6.0
#
#         Nom 1     Prénom 1 Code Nuance 1 Voix 1  ... Sièges 30 Nuance 31  \
# 0  TORREMOCHA       Sandra          LEXG      1  ...       NaN      <NA>
# 1    MARTINEZ  Jean-Claude          LDVD      3  ...       NaN      <NA>
# 2         JUY      Monique          LDIV      2  ...       NaN      <NA>
# 3        BOV�         Jos�          LVEC     46  ...       NaN      <NA>
# 4       ALIOT        Louis           LFN    245  ...       NaN      <NA>
#
#   Libellé Abrégé Liste 31  Sièges 31 Nuance 32 Libellé Abrégé Liste 32  \
# 0                    <NA>        NaN      <NA>                    <NA>
# 1                    <NA>        NaN      <NA>                    <NA>
# 2                    <NA>        NaN      <NA>                    <NA>
# 3                    <NA>        NaN      <NA>                    <NA>
# 4                    <NA>        NaN      <NA>                    <NA>
#
#    Sièges 32 Nuance 33  Libellé Abrégé Liste 33 Sièges 33 Nuance 34  \
# 0        NaN      <NA>                     <NA>       NaN      <NA>
# 1        NaN      <NA>                     <NA>       NaN      <NA>
# 2        NaN      <NA>                     <NA>       NaN      <NA>
# 3        NaN      <NA>                     <NA>       NaN      <NA>
# 4        NaN      <NA>                     <NA>       NaN      <NA>
#
#   Libellé Abrégé Liste 34 Sièges 34 Nuance 35 Libellé Abrégé Liste 35  \
# 0                    <NA>       NaN      <NA>                    <NA>
# 1                    <NA>       NaN      <NA>                    <NA>
# 2                    <NA>       NaN      <NA>                    <NA>
# 3                    <NA>       NaN      <NA>                    <NA>
# 4                    <NA>       NaN      <NA>                    <NA>
#
#   Sièges 35 Nuance 36 Libellé Abrégé Liste 36 Sièges 36  Nuance 37  \
# 0       NaN      <NA>                    <NA>       NaN       <NA>
# 1       NaN      <NA>                    <NA>       NaN       <NA>
# 2       NaN      <NA>                    <NA>       NaN       <NA>
# 3       NaN      <NA>                    <NA>       NaN       <NA>
# 4       NaN      <NA>                    <NA>       NaN       <NA>
#
#   Libellé Abrégé Liste 37 Sièges 37 Nuance 38 Libellé Abrégé Liste 38  \
# 0                    <NA>       NaN      <NA>                    <NA>
# 1                    <NA>       NaN      <NA>                    <NA>
# 2                    <NA>       NaN      <NA>                    <NA>
# 3                    <NA>       NaN      <NA>                    <NA>
# 4                    <NA>       NaN      <NA>                    <NA>
#
#    Sièges 38
# 0        NaN
# 1        NaN
# 2        NaN
# 3        NaN
# 4        NaN
#
# [5 rows x 889 columns]

# %% [markdown]
# ## Mapping candidats -> blocs politiques

# %%
mapping = pd.read_csv(mapping_path, sep=";")
elections_long = elections_long.merge(mapping, on="code_candidature", how="left")
elections_long.head()
# Out:
#      code_bv  nom_bv  annee date_scrutin type_scrutin  tour  inscrits  \
# 0  000010001     NaN   2014   2014-05-25  europeennes     1      1193
# 1  000010001     NaN   2014   2014-05-25  europeennes     1      1193
# 2  000010001     NaN   2014   2014-05-25  europeennes     1      1193
# 3  000010001     NaN   2014   2014-05-25  europeennes     1      1193
# 4  000010001     NaN   2014   2014-05-25  europeennes     1      1193
#
#    votants  abstentions  blancs  nuls  exprimes code_candidature  \
# 0      566          NaN     NaN   NaN       549             <NA>
# 1      566          NaN     NaN   NaN       549             <NA>
# 2      566          NaN     NaN   NaN       549             <NA>
# 3      566          NaN     NaN   NaN       549             <NA>
# 4      566          NaN     NaN   NaN       549             <NA>
#
#   nom_candidature_x  voix  N° tour Code du département Code de la commune  \
# 0              <NA>   0.0      1.0                  34                  1
# 1              <NA>   0.0      1.0                  34                  1
# 2              <NA>   0.0      1.0                  34                  1
# 3              <NA>   0.0      1.0                  34                  1
# 4              <NA>   0.0      1.0                  34                  1
#
#   Nom de la commune Numéro bureau de vote  NÂ° de dépôt du candidat 1  \
# 0          Abeilhan                  0001                         2.0
# 1          Abeilhan                  0001                         3.0
# 2          Abeilhan                  0001                         4.0
# 3          Abeilhan                  0001                         5.0
# 4          Abeilhan                  0001                         6.0
#
#         Nom 1     Prénom 1 Code Nuance 1 Voix 1  ... Nuance 32  \
# 0  TORREMOCHA       Sandra          LEXG      1  ...      <NA>
# 1    MARTINEZ  Jean-Claude          LDVD      3  ...      <NA>
# 2         JUY      Monique          LDIV      2  ...      <NA>
# 3        BOV�         Jos�          LVEC     46  ...      <NA>
# 4       ALIOT        Louis           LFN    245  ...      <NA>
#
#   Libellé Abrégé Liste 32 Sièges 32  Nuance 33 Libellé Abrégé Liste 33  \
# 0                    <NA>       NaN       <NA>                    <NA>
# 1                    <NA>       NaN       <NA>                    <NA>
# 2                    <NA>       NaN       <NA>                    <NA>
# 3                    <NA>       NaN       <NA>                    <NA>
# 4                    <NA>       NaN       <NA>                    <NA>
#
#   Sièges 33  Nuance 34 Libellé Abrégé Liste 34  Sièges 34 Nuance 35  \
# 0       NaN       <NA>                    <NA>        NaN      <NA>
# 1       NaN       <NA>                    <NA>        NaN      <NA>
# 2       NaN       <NA>                    <NA>        NaN      <NA>
# 3       NaN       <NA>                    <NA>        NaN      <NA>
# 4       NaN       <NA>                    <NA>        NaN      <NA>
#
#   Libellé Abrégé Liste 35 Sièges 35 Nuance 36 Libellé Abrégé Liste 36  \
# 0                    <NA>       NaN      <NA>                    <NA>
# 1                    <NA>       NaN      <NA>                    <NA>
# 2                    <NA>       NaN      <NA>                    <NA>
# 3                    <NA>       NaN      <NA>                    <NA>
# 4                    <NA>       NaN      <NA>                    <NA>
#
#   Sièges 36 Nuance 37 Libellé Abrégé Liste 37 Sièges 37 Nuance 38  \
# 0       NaN      <NA>                    <NA>       NaN      <NA>
# 1       NaN      <NA>                    <NA>       NaN      <NA>
# 2       NaN      <NA>                    <NA>       NaN      <NA>
# 3       NaN      <NA>                    <NA>       NaN      <NA>
# 4       NaN      <NA>                    <NA>       NaN      <NA>
#
#    Libellé Abrégé Liste 38 Sièges 38 nom_candidature_y bloc_1 bloc_2  bloc_3
# 0                     <NA>       NaN               NaN    NaN    NaN     NaN
# 1                     <NA>       NaN               NaN    NaN    NaN     NaN
# 2                     <NA>       NaN               NaN    NaN    NaN     NaN
# 3                     <NA>       NaN               NaN    NaN    NaN     NaN
# 4                     <NA>       NaN               NaN    NaN    NaN     NaN
#
# [5 rows x 893 columns]

# %% [markdown]
# ## Repartition des voix par bloc

# %%
from pathlib import Path
import sys
PROJECT_ROOT = Path.cwd().resolve()
if PROJECT_ROOT.name == "notebooks":
    PROJECT_ROOT = PROJECT_ROOT.parent
sys.path.append(str(PROJECT_ROOT))
import pandas as pd
import numpy as np
def voix_par_bloc(row) -> dict:
    blocs = [row.get("bloc_1"), row.get("bloc_2"), row.get("bloc_3")]
    blocs = [b for b in blocs if isinstance(b, str) and b]
    if not blocs:
        # fallback pour nuances non mappees : regrouper dans "divers"
        return {"divers": row.get("voix", 0)}
    part = row.get("voix", 0) / len(blocs)
    return {b: part for b in blocs}
records: list[dict] = []
for _, row in elections_long.iterrows():
    repartition = voix_par_bloc(row)
    for bloc, v in repartition.items():
        records.append(
            {
                "code_bv": row["code_bv"],
                "nom_bv": row.get("nom_bv"),
                "date_scrutin": row["date_scrutin"],
                "annee": row["annee"],
                "type_scrutin": row["type_scrutin"],
                "tour": row["tour"],
                "bloc": bloc,
                "voix_bloc": v,
                "exprimes": row["exprimes"],
                "inscrits": row["inscrits"],
                "votants": row["votants"],
            }
        )
elections_blocs = pd.DataFrame.from_records(records)
elections_blocs["part_bloc"] = elections_blocs["voix_bloc"] / elections_blocs["exprimes"]
elections_blocs.head()
# Out:
#      code_bv  nom_bv date_scrutin  annee type_scrutin  tour    bloc  \
# 0  000010001     NaN   2014-05-25   2014  europeennes     1  divers
# 1  000010001     NaN   2014-05-25   2014  europeennes     1  divers
# 2  000010001     NaN   2014-05-25   2014  europeennes     1  divers
# 3  000010001     NaN   2014-05-25   2014  europeennes     1  divers
# 4  000010001     NaN   2014-05-25   2014  europeennes     1  divers
#
#    voix_bloc  exprimes  inscrits  votants  part_bloc
# 0        0.0       549      1193      566        0.0
# 1        0.0       549      1193      566        0.0
# 2        0.0       549      1193      566        0.0
# 3        0.0       549      1193      566        0.0
# 4        0.0       549      1193      566        0.0

# %% [markdown]
# ## Références nationales calculées automatiquement
# Agrégation du score/participation national par scrutin & bloc si aucun fichier externe n'est fourni.

# %%
from src.pipeline import compute_national_reference, filter_target_communes, load_target_communes

# Calcul des références nationales directement à partir des données si aucune table externe
nat_ref = compute_national_reference(elections_blocs)

# Fusion des références nationales
elections_blocs = elections_blocs.merge(nat_ref, on=["date_scrutin", "bloc"], how="left")

# Écarts locaux vs national
elections_blocs["taux_participation_bv"] = elections_blocs["votants"] / elections_blocs["inscrits"]
elections_blocs["ecart_bloc_vs_national"] = elections_blocs["part_bloc"] - elections_blocs["part_bloc_national"]
elections_blocs["ecart_participation_vs_nat"] = (
    elections_blocs["taux_participation_bv"] - elections_blocs["taux_participation_national"]
)

# Restreindre aux communes cibles pour alléger la suite
target_communes = load_target_communes()
elections_blocs = filter_target_communes(elections_blocs, target_communes)

# %% [markdown]
# ## Evolution de la population inscrite

# %%
bv_pop = elections_blocs.groupby(["code_bv", "annee"], as_index=False)["inscrits"].mean()
base_year = 2014
bv_base = (
    bv_pop[bv_pop["annee"] == base_year][["code_bv", "inscrits"]]
    .rename(columns={"inscrits": "inscrits_base"})
)
bv_pop = bv_pop.merge(bv_base, on="code_bv", how="left")
bv_pop["croissance_inscrits_depuis_base"] = (
    bv_pop["inscrits"] - bv_pop["inscrits_base"]
) / bv_pop["inscrits_base"]

elections_blocs = elections_blocs.merge(
    bv_pop[["code_bv", "annee", "croissance_inscrits_depuis_base"]],
    on=["code_bv", "annee"],
    how="left",
)

# %% [markdown]
# ## Lags et variables de contexte

# %%
elections_blocs = elections_blocs.sort_values(["code_bv", "bloc", "date_scrutin"])
elections_blocs["part_bloc_lag1"] = elections_blocs.groupby(["code_bv", "bloc"])["part_bloc"].shift(1)
elections_blocs["ecart_bloc_vs_national_lag1"] = (
    elections_blocs.groupby(["code_bv", "bloc"])["ecart_bloc_vs_national"].shift(1)
)
elections_blocs["taux_participation_bv_lag1"] = (
    elections_blocs.groupby(["code_bv", "bloc"])["taux_participation_bv"].shift(1)
)
elections_blocs["annee_centre"] = elections_blocs["annee"] - elections_blocs["annee"].median()

elections_blocs.head()
# Out:
#        code_bv  nom_bv date_scrutin  annee type_scrutin  tour    bloc  \
# 750  343010001     NaN   2014-03-23   2014  municipales     1  divers
# 751  343010001     NaN   2014-03-23   2014  municipales     1  divers
# 752  343010001     NaN   2014-03-23   2014  municipales     1  divers
# 753  343010001     NaN   2014-03-23   2014  municipales     1  divers
# 754  343010001     NaN   2014-03-23   2014  municipales     1  divers
#
#      voix_bloc  exprimes  inscrits  votants  part_bloc  part_bloc_national  \
# 750        0.0       641       962      647        0.0                 0.0
# 751        0.0       641       962      647        0.0                 0.0
# 752        0.0       641       962      647        0.0                 0.0
# 753        0.0       641       962      647        0.0                 0.0
# 754        0.0       641       962      647        0.0                 0.0
#
#      taux_participation_national  taux_participation_bv  \
# 750                     0.668182               0.672557
# 751                     0.668182               0.672557
# 752                     0.668182               0.672557
# 753                     0.668182               0.672557
# 754                     0.668182               0.672557
#
#      ecart_bloc_vs_national  ecart_participation_vs_nat code_commune  \
# 750                     0.0                    0.004375        34301
# 751                     0.0                    0.004375        34301
# 752                     0.0                    0.004375        34301
# 753                     0.0                    0.004375        34301
# 754                     0.0                    0.004375        34301
#
#     nom_commune  croissance_inscrits_depuis_base  part_bloc_lag1  \
# 750        Sete                              0.0             NaN
# 751        Sete                              0.0             0.0
# 752        Sete                              0.0             0.0
# 753        Sete                              0.0             0.0
# 754        Sete                              0.0             0.0
#
#      ecart_bloc_vs_national_lag1  taux_participation_bv_lag1  annee_centre
# 750                          NaN                         NaN           0.0
# 751                          0.0                    0.672557           0.0
# 752                          0.0                    0.672557           0.0
# 753                          0.0                    0.672557           0.0
# 754                          0.0                    0.672557           0.0

# %% [markdown]
# ## Sauvegarde

# %%
PROCESSED_DIR.mkdir(parents=True, exist_ok=True)
elections_blocs.to_parquet(PROCESSED_DIR / "elections_blocs.parquet", index=False)
elections_blocs.to_csv(PROCESSED_DIR / "elections_blocs.csv", sep=";", index=False)
elections_blocs.shape
# Out:
# (1650, 24)
